# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
batch_size = 32
img_height = 250
img_width = 250

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  "Eye_diseases",
  validation_split=0.8,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 610 files belonging to 7 classes.
# Using 122 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  "Eye_diseases",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 610 files belonging to 7 classes.
# Using 122 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bulging_Eyes', 'Cataracts', 'Crossed_Eyes', 'Glaucoma', 'Keratoconus', 'Uveitis', 'normal']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 250, 250, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 250, 250, 3)       0
#
#  conv2d (Conv2D)             (None, 250, 250, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 125, 125, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 62, 62, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 61504)             0
#
#  dense (Dense)               (None, 128)               7872640
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,897,127
# Trainable params: 7,897,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=40
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 9s 2s/step - loss: 4.0999 - accuracy: 0.1639 - val_loss: 1.9052 - val_accuracy: 0.3033
# Epoch 2/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.9161 - accuracy: 0.4180 - val_loss: 1.9610 - val_accuracy: 0.3033
# Epoch 3/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.7778 - accuracy: 0.4180 - val_loss: 1.8740 - val_accuracy: 0.3033
# Epoch 4/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.6708 - accuracy: 0.4180 - val_loss: 1.7777 - val_accuracy: 0.3033
# Epoch 5/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.5811 - accuracy: 0.5082 - val_loss: 1.7844 - val_accuracy: 0.2951
# Epoch 6/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.4560 - accuracy: 0.4754 - val_loss: 1.8453 - val_accuracy: 0.3115
# Epoch 7/40
# 4/4 [==============================] - 7s 2s/step - loss: 1.2695 - accuracy: 0.4918 - val_loss: 1.8517 - val_accuracy: 0.2951
# Epoch 8/40
# 4/4 [==============================] - 7s 2s/step - loss: 1.0598 - accuracy: 0.6148 - val_loss: 1.8791 - val_accuracy: 0.3197
# Epoch 9/40
# 4/4 [==============================] - 9s 2s/step - loss: 0.9382 - accuracy: 0.7213 - val_loss: 2.0215 - val_accuracy: 0.3279
# Epoch 10/40
# 4/4 [==============================] - 7s 2s/step - loss: 0.6812 - accuracy: 0.7295 - val_loss: 2.0703 - val_accuracy: 0.3525
# Epoch 11/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.4746 - accuracy: 0.8934 - val_loss: 2.4385 - val_accuracy: 0.3525
# Epoch 12/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.2863 - accuracy: 0.9508 - val_loss: 3.0141 - val_accuracy: 0.3197
# Epoch 13/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.1930 - accuracy: 0.9426 - val_loss: 3.6195 - val_accuracy: 0.2459
# Epoch 14/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.3787 - accuracy: 0.9098 - val_loss: 2.6823 - val_accuracy: 0.3033
# Epoch 15/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.2675 - accuracy: 0.9098 - val_loss: 2.8607 - val_accuracy: 0.2541
# Epoch 16/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.1183 - accuracy: 0.9836 - val_loss: 3.3407 - val_accuracy: 0.3033
# Epoch 17/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.0625 - accuracy: 0.9918 - val_loss: 3.9666 - val_accuracy: 0.3525
# Epoch 18/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0369 - accuracy: 0.9918 - val_loss: 4.3592 - val_accuracy: 0.3443
# Epoch 19/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 4.5678 - val_accuracy: 0.3115
# Epoch 20/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 4.5765 - val_accuracy: 0.3279
# Epoch 21/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 4.5817 - val_accuracy: 0.3443
# Epoch 22/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 4.6570 - val_accuracy: 0.3279
# Epoch 23/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 4.7626 - val_accuracy: 0.3361
# Epoch 24/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 4.9000 - val_accuracy: 0.3279
# Epoch 25/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.0667 - val_accuracy: 0.2951
# Epoch 26/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.2169 - val_accuracy: 0.2787
# Epoch 27/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.3529 - val_accuracy: 0.2787
# Epoch 28/40
# 4/4 [==============================] - 5s 1s/step - loss: 8.6180e-04 - accuracy: 1.0000 - val_loss: 5.4695 - val_accuracy: 0.2951
# Epoch 29/40
# 4/4 [==============================] - 5s 1s/step - loss: 7.2817e-04 - accuracy: 1.0000 - val_loss: 5.5704 - val_accuracy: 0.3033
# Epoch 30/40
# 4/4 [==============================] - 5s 1s/step - loss: 6.1074e-04 - accuracy: 1.0000 - val_loss: 5.6444 - val_accuracy: 0.2951
# Epoch 31/40
# 4/4 [==============================] - 5s 1s/step - loss: 5.5117e-04 - accuracy: 1.0000 - val_loss: 5.7015 - val_accuracy: 0.3115
# Epoch 32/40
# 4/4 [==============================] - 5s 1s/step - loss: 4.9433e-04 - accuracy: 1.0000 - val_loss: 5.7485 - val_accuracy: 0.3115
# Epoch 33/40
# 4/4 [==============================] - 5s 1s/step - loss: 4.4629e-04 - accuracy: 1.0000 - val_loss: 5.7907 - val_accuracy: 0.3115
# Epoch 34/40
# 4/4 [==============================] - 5s 1s/step - loss: 4.1872e-04 - accuracy: 1.0000 - val_loss: 5.8245 - val_accuracy: 0.3033
# Epoch 35/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.9295e-04 - accuracy: 1.0000 - val_loss: 5.8561 - val_accuracy: 0.3033
# Epoch 36/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.7035e-04 - accuracy: 1.0000 - val_loss: 5.8840 - val_accuracy: 0.2951
# Epoch 37/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.5337e-04 - accuracy: 1.0000 - val_loss: 5.9081 - val_accuracy: 0.2951
# Epoch 38/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.3508e-04 - accuracy: 1.0000 - val_loss: 5.9313 - val_accuracy: 0.2951
# Epoch 39/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.2046e-04 - accuracy: 1.0000 - val_loss: 5.9530 - val_accuracy: 0.2951
# Epoch 40/40
# 4/4 [==============================] - 5s 1s/step - loss: 3.0845e-04 - accuracy: 1.0000 - val_loss: 5.9702 - val_accuracy: 0.2951

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 250, 250, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 250, 250, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 250, 250, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 125, 125, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 62, 62, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 31, 31, 64)        0
#
#  flatten_1 (Flatten)         (None, 61504)             0
#
#  dense_2 (Dense)             (None, 128)               7872640
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,897,127
# Trainable params: 7,897,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 40
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 6s 1s/step - loss: 3.4926 - accuracy: 0.2705 - val_loss: 2.0700 - val_accuracy: 0.3115
# Epoch 2/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.9185 - accuracy: 0.4016 - val_loss: 1.9280 - val_accuracy: 0.3033
# Epoch 3/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.8617 - accuracy: 0.4016 - val_loss: 1.8922 - val_accuracy: 0.3033
# Epoch 4/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.8082 - accuracy: 0.4016 - val_loss: 1.8776 - val_accuracy: 0.3033
# Epoch 5/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.7210 - accuracy: 0.4016 - val_loss: 1.7904 - val_accuracy: 0.3033
# Epoch 6/40
# 4/4 [==============================] - 8s 2s/step - loss: 1.6736 - accuracy: 0.4016 - val_loss: 1.7835 - val_accuracy: 0.3033
# Epoch 7/40
# 4/4 [==============================] - 7s 2s/step - loss: 1.6474 - accuracy: 0.4016 - val_loss: 1.7665 - val_accuracy: 0.3033
# Epoch 8/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.6067 - accuracy: 0.4180 - val_loss: 1.8285 - val_accuracy: 0.3115
# Epoch 9/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.5624 - accuracy: 0.4262 - val_loss: 1.7781 - val_accuracy: 0.3115
# Epoch 10/40
# 4/4 [==============================] - 6s 1s/step - loss: 1.5381 - accuracy: 0.4262 - val_loss: 1.7715 - val_accuracy: 0.3033
# Epoch 11/40
# 4/4 [==============================] - 6s 1s/step - loss: 1.5062 - accuracy: 0.4426 - val_loss: 1.7555 - val_accuracy: 0.3115
# Epoch 12/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.4670 - accuracy: 0.4590 - val_loss: 1.8159 - val_accuracy: 0.3115
# Epoch 13/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.3909 - accuracy: 0.5000 - val_loss: 1.7941 - val_accuracy: 0.2951
# Epoch 14/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.3653 - accuracy: 0.4918 - val_loss: 1.7658 - val_accuracy: 0.3197
# Epoch 15/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.3225 - accuracy: 0.5082 - val_loss: 1.8754 - val_accuracy: 0.3361
# Epoch 16/40
# 4/4 [==============================] - 5s 1s/step - loss: 1.3157 - accuracy: 0.5246 - val_loss: 1.7830 - val_accuracy: 0.3770
# Epoch 17/40
# 4/4 [==============================] - 6s 1s/step - loss: 1.2476 - accuracy: 0.5738 - val_loss: 1.8294 - val_accuracy: 0.3689
# Epoch 18/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.2913 - accuracy: 0.5164 - val_loss: 1.8271 - val_accuracy: 0.3770
# Epoch 19/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.1840 - accuracy: 0.5738 - val_loss: 1.9333 - val_accuracy: 0.3361
# Epoch 20/40
# 4/4 [==============================] - 6s 1s/step - loss: 1.1949 - accuracy: 0.5738 - val_loss: 2.1490 - val_accuracy: 0.3115
# Epoch 21/40
# 4/4 [==============================] - 6s 2s/step - loss: 1.1089 - accuracy: 0.5902 - val_loss: 2.1078 - val_accuracy: 0.3525
# Epoch 22/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.9787 - accuracy: 0.6230 - val_loss: 2.0829 - val_accuracy: 0.3279
# Epoch 23/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.9415 - accuracy: 0.6475 - val_loss: 2.1957 - val_accuracy: 0.3770
# Epoch 24/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.8032 - accuracy: 0.7049 - val_loss: 2.1614 - val_accuracy: 0.3770
# Epoch 25/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.8522 - accuracy: 0.6803 - val_loss: 2.4310 - val_accuracy: 0.3689
# Epoch 26/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.7343 - accuracy: 0.7623 - val_loss: 2.4547 - val_accuracy: 0.3443
# Epoch 27/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.6435 - accuracy: 0.7869 - val_loss: 2.4796 - val_accuracy: 0.3689
# Epoch 28/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.6548 - accuracy: 0.7541 - val_loss: 2.7837 - val_accuracy: 0.3115
# Epoch 29/40
# 4/4 [==============================] - 6s 2s/step - loss: 0.5939 - accuracy: 0.7459 - val_loss: 2.6426 - val_accuracy: 0.3607
# Epoch 30/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.5160 - accuracy: 0.8197 - val_loss: 2.7348 - val_accuracy: 0.3443
# Epoch 31/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.4667 - accuracy: 0.8443 - val_loss: 3.2946 - val_accuracy: 0.3033
# Epoch 32/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.6635 - accuracy: 0.7705 - val_loss: 2.9993 - val_accuracy: 0.2869
# Epoch 33/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.5710 - accuracy: 0.8115 - val_loss: 2.8680 - val_accuracy: 0.3279
# Epoch 34/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.5222 - accuracy: 0.8361 - val_loss: 3.2616 - val_accuracy: 0.3033
# Epoch 35/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.3624 - accuracy: 0.8689 - val_loss: 3.2375 - val_accuracy: 0.3279
# Epoch 36/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.4072 - accuracy: 0.8525 - val_loss: 3.5138 - val_accuracy: 0.3115
# Epoch 37/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.4018 - accuracy: 0.8852 - val_loss: 3.6170 - val_accuracy: 0.2869
# Epoch 38/40
# 4/4 [==============================] - 6s 1s/step - loss: 0.3181 - accuracy: 0.8934 - val_loss: 3.9664 - val_accuracy: 0.2869
# Epoch 39/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.3281 - accuracy: 0.8607 - val_loss: 3.6201 - val_accuracy: 0.3525
# Epoch 40/40
# 4/4 [==============================] - 5s 1s/step - loss: 0.2820 - accuracy: 0.8934 - val_loss: 4.0901 - val_accuracy: 0.3689

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in val_ds.take(1):
    
    first_image = images_batch[3].numpy().astype('uint8')
    first_label = labels_batch[3].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Crossed_Eyes
# 1/1 [==============================] - 4s 4s/step
# predicted label: Uveitis

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in val_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
import os
model_version=max([int(i) for i in os.listdir("../saved_models") + [0]])+1
model.save(f"../models/{model_version}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/1\assets
# INFO:tensorflow:Assets written to: ../models/1\assets
